# %% [markdown]
# ## Top 10 movies
# or something i couldn't remember what the task was so..
#
# #### TODO:
#  - read data
#  - filter data
#  - that was simple enough

# %%
import pandas as pd

# %%
#Read csv file into a dataframe
df = pd.read_csv("movies.csv")

# %%
df.sort_values(by=['runtime'], inplace=True, ascending=False)
topTenRunTime = df[:10]
topTenRunTime
# Out:
#         budget    revenue                                     original_title  \
# 15    44000000  155760117                                  The Hateful Eight
# 5    135000000  532950503                                       The Revenant
# 10   245000000  880674609                                            Spectre
# 40    28000000  201634991                             Straight Outta Compton
# 33    40000000  162610473                                    Bridge of Spies
# ..         ...        ...                                                ...
# 185          0          0                            Halo: The Fall of Reach
# 181          0          0  LEGO DC Comics Super Heroes: Justice League vs...
# 159     630019          0                                          Kung Fury
# 100          0          0                                       Frozen Fever
# 92           0          0                           Mythica: The Necromancer
#
#                                                   cast  \
# 15   Samuel L. Jackson|Kurt Russell|Jennifer Jason ...
# 5    Leonardo DiCaprio|Tom Hardy|Will Poulter|Domhn...
# 10   Daniel Craig|Christoph Waltz|LÃ©a Seydoux|Ralp...
# 40   O'Shea Jackson Jr.|Corey Hawkins|Jason Mitchel...
# 33   Tom Hanks|Mark Rylance|Amy Ryan|Alan Alda|Seba...
# ..                                                 ...
# 185  Steve Downes|Jen Taylor|Michelle Lukes|Travis ...
# 181  Nolan North|Troy Baker|Diedrich Bader|Khary Pa...
# 159  David Sandberg|Jorma Taccone|Leopold Nilsson|A...
# 100  Kristen Bell|Idina Menzel|Jonathan Groff|Josh ...
# 92   Melanie Stone|Adam Johnson|Kevin Sorbo|Nicola ...
#
#                            director  runtime  \
# 15                Quentin Tarantino      167
# 5    Alejandro GonzÃ¡lez IÃ±Ã¡rritu      156
# 10                       Sam Mendes      148
# 40                     F. Gary Gray      147
# 33                 Steven Spielberg      141
# ..                              ...      ...
# 185                       Ian Kirby       67
# 181                  Brandon Vietti       48
# 159                  David Sandberg       31
# 100         Chris Buck|Jennifer Lee        8
# 92                    A. Todd Smith        0
#
#                                     genres release_date  release_year
# 15             Crime|Drama|Mystery|Western     12/25/15          2015
# 5         Western|Drama|Adventure|Thriller     12/25/15          2015
# 10                  Action|Adventure|Crime     10/26/15          2015
# 40                             Drama|Music      8/13/15          2015
# 33                          Thriller|Drama     10/15/15          2015
# ..                                     ...          ...           ...
# 185       Action|Animation|Science Fiction     10/27/15          2015
# 181      Action|Adventure|Animation|Family      2/10/15          2015
# 159  Action|Comedy|Science Fiction|Fantasy      5/28/15          2015
# 100             Adventure|Animation|Family       3/9/15          2015
# 92                Fantasy|Action|Adventure     12/19/15          2015
#
# [201 rows x 9 columns]

# %% [markdown]
# ### One month passes by now we have to plot stuff too...
# - plot the top ten movie on a graph i guess

# %%
import matplotlib.pyplot as plt

# %%
topTenRunTime.plot(x='original_title', y='runtime', kind='scatter')
plt.show()
